# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeiVKalinin/MSE_Fall_2025/blob/main/Module%206/27_QM9_data_parsing_SELFIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook shows how to extract information from QM9 dataset, particularly from each molecule (given originally in .xyz format) followed by computing features using rdkit and then combine those into a dataframe.
#
#
#
# ### Notebook prepared by Ayana Ghosh
#
# ### Email: research.aghosh@gmail.com

# %% [markdown]
# ### Link to orginal dataset:
#
# http://quantum-machine.org/datasets/

# %% [markdown]
# ### Link where we can find the functionalities represented by variables in the 'parser' code. For example 'mu' represents the dipole moment.
#
# https://pytorch-geometric.readthedocs.io/en/latest/generated/torch_geometric.datasets.QM9.html

# %% [markdown]
# Install rdkit

# %%
# !pip install rdkit #-pypi
# !pip install wget
#!pip install selfies

# !pip install selfies --upgrade
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (36.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 42.0 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.1
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=724b691b58e64ba0ec6f824b3f232d18bc489ba7bf235314d14bd70e60e81245
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Collecting selfies
#   Downloading selfies-2.2.0-py3-none-any.whl.metadata (14 kB)
# Downloading selfies-2.2.0-py3-none-any.whl (36 kB)
# Installing collected packages: selfies
# Successfully installed selfies-2.2.0

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd

import glob
import wget

import rdkit
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import rdMolDescriptors

import torch
from math import log
import matplotlib.pyplot as plt
from pandas import json_normalize

import selfies as sf

# %% [markdown]
# Mount Google Drive

# %%
'''
from google.colab import drive
drive.mount('/content/drive')
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/drive')\n"

# %%
#@title Helper functions for parsing
def parse_float(s: str) -> float:
    try:
        return float(s)
    except ValueError:
        base, power = s.split('*^')
        return float(base) * 10**float(power)


def parse_xyz(filename):
    """
    Parses QM9 specific xyz files.
    :param filename: str path to file
    :return:
    """
    num_atoms = 0
    scalar_properties = []
    atomic_symbols = []
    xyz = []
    charges = []
    harmonic_vibrational_frequencies = []
    smiles = ''
    inchi = ''
    with open(filename, 'r') as f:
        for line_num, line in enumerate(f):
            if line_num == 0:
                num_atoms = int(line)
            elif line_num == 1:
                scalar_properties = [float(i) for i in line.split()[2:]]
            elif 2 <= line_num <= 1 + num_atoms:
                atom_symbol, x, y, z, charge = line.split()
                atomic_symbols.append(atom_symbol)
                xyz.append([parse_float(x), parse_float(y), parse_float(z)])
                charges.append(parse_float(charge))
            elif line_num == num_atoms + 2:
                harmonic_vibrational_frequencies = [float(i) for i in line.split()]
            elif line_num == num_atoms + 3:
                smiles = line.split()[0]
            elif line_num == num_atoms + 4:
                inchi = line.split()[0]

    result = {
        'num_atoms': num_atoms,
        'atomic_symbols': atomic_symbols,
        'pos': torch.tensor(xyz),
        'charges': np.array(charges),
        'harmonic_oscillator_frequencies': harmonic_vibrational_frequencies,
        'smiles': smiles,
        'inchi': inchi
    }
    scalar_property_labels = ['A', 'B', 'C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'r2', 'zpve', 'u0', 'u', 'h', 'g', 'cv']
    scalar_properties = dict(zip(scalar_property_labels, scalar_properties))
    result.update(scalar_properties)
    return result

# %% [markdown]
# ### Here, we only use 20 molecules form QM9 to show an example.
#
# ### Let's download the data

# %%
# !gdown https://drive.google.com/uc?id=1At3XHtaXXY3Qr4RIQ1Vua2_dRKoGyyEF
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1At3XHtaXXY3Qr4RIQ1Vua2_dRKoGyyEF
# From (redirected): https://drive.google.com/uc?id=1At3XHtaXXY3Qr4RIQ1Vua2_dRKoGyyEF&confirm=t&uuid=194c24f0-ef7d-42c5-b250-aeac7de21902
# To: /content/dsgdb9nsd.xyz.tar.bz2
# 100% 86.1M/86.1M [00:01<00:00, 58.9MB/s]

# %%
#!wget -O QM9_molecules.zip https://www.dropbox.com/scl/fi/efc5fa4mqex3t2xa0zvi5/QM9_molecules.zip?rlkey=i47z08elmeach0xrkh32ukafo&dl=0
#!unzip QM9_molecules.zip -d '/content/drive/MyyDrive/'

# %% [markdown]
# Generate lists of SMILE strings and append with properties that we can directly retrieve from the QM9 dataset

# %%
# prompt: create folde rMolecules and unzip /content/dsgdb9nsd.xyz.tar.bz2 into folder Molecules

# !mkdir /content/Molecules
# !tar -C Molecules -xvf /content/dsgdb9nsd.xyz.tar.bz2
# Out:
# Streaming output truncated to the last 5000 lines.
# dsgdb9nsd_128886.xyz
# dsgdb9nsd_128887.xyz
# dsgdb9nsd_128888.xyz
# dsgdb9nsd_128889.xyz
# dsgdb9nsd_128890.xyz
# dsgdb9nsd_128891.xyz
# dsgdb9nsd_128892.xyz
# dsgdb9nsd_128893.xyz
# dsgdb9nsd_128894.xyz
# dsgdb9nsd_128895.xyz
# dsgdb9nsd_128896.xyz
# dsgdb9nsd_128897.xyz
# dsgdb9nsd_128898.xyz
# dsgdb9nsd_128899.xyz
# dsgdb9nsd_128900.xyz
# dsgdb9nsd_128901.xyz
# dsgdb9nsd_128902.xyz
# dsgdb9nsd_128903.xyz
# dsgdb9nsd_128904.xyz
# dsgdb9nsd_128905.xyz
# dsgdb9nsd_128906.xyz
# dsgdb9nsd_128907.xyz
# dsgdb9nsd_128908.xyz
# dsgdb9nsd_128909.xyz
# dsgdb9nsd_128910.xyz
# dsgdb9nsd_128911.xyz
# dsgdb9nsd_128912.xyz
# dsgdb9nsd_128913.xyz
# dsgdb9nsd_128914.xyz
# dsgdb9nsd_128915.xyz
# dsgdb9nsd_128916.xyz
# dsgdb9nsd_128917.xyz
# dsgdb9nsd_128918.xyz
# dsgdb9nsd_128919.xyz
# dsgdb9nsd_128920.xyz
# dsgdb9nsd_128921.xyz
# dsgdb9nsd_128922.xyz
# dsgdb9nsd_128923.xyz
# dsgdb9nsd_128924.xyz
# dsgdb9nsd_128925.xyz
# dsgdb9nsd_128926.xyz
# dsgdb9nsd_128927.xyz
# dsgdb9nsd_128928.xyz
# dsgdb9nsd_128929.xyz
# dsgdb9nsd_128930.xyz
    enthalpy_loc = x['h']
    dipole_moment = x['mu']
    homo_loc = x['homo']
    lumo_loc = x['lumo']
    gap_loc = x['gap']
    zpve_loc = x['zpve']
    u0_loc = x['u0']
    u_loc = x['u']
    g_loc = x['g']
    alpha_loc = x['alpha']
    r2_loc = x['r2']
    smiles.append(smiles_loc)
    mu.append(dipole_moment)
    enthalpy.append(enthalpy_loc)
    u0.append(u0_loc)
    u.append(u_loc)
    g.append(g_loc)
    alpha.append(alpha_loc)
    r2.append(r2_loc)

# %% [markdown]
# Let's compute few basic features and put together a dataset.
#
# Features we compute:
# molecular weight, topological polar surface area, molar log P,
# number of hydrogen bond donors, acceptors, valence electrons, maximum partial charge, minimum partial charge, number of rotatable bonds, number of ring counts, number of stereocenters

# %%
mol_wt, tpsa, logp_ml, hbd, hba  = [], [], [], [], []
vale, partialcg_max, partialcg_min, rotbd, ringct, stereoct = [], [], [], [], [], []

for i in range(len(smiles)):
    m = Chem.MolFromSmiles(smiles[i])
    mol_wt_l = Descriptors.ExactMolWt(m)
    tpsa_l, logp_l = Descriptors.TPSA(m), Descriptors.MolLogP(m)
    hbd_l, hba_l = Descriptors.NumHDonors(m), Descriptors.NumHAcceptors(m)
    vale_l = Descriptors.NumValenceElectrons(m),
    partialcharge_max_l, partialcharge_min_l = Descriptors.MaxPartialCharge(m), Descriptors.MinPartialCharge(m)
    rotbd_l = Descriptors.NumRotatableBonds(m)
    ring_ct, stereo_cent = Descriptors.RingCount(m), rdMolDescriptors.CalcNumAtomStereoCenters(m)

    mol_wt.append(mol_wt_l)
    tpsa.append(tpsa_l)
    logp_ml.append(logp_l)
    hbd.append(hbd_l)
    hba.append(hba_l)
    vale.append(vale_l)
    partialcg_max.append(partialcharge_max_l)
    partialcg_min.append(partialcharge_min_l)
    rotbd.append(rotbd_l)
    ringct.append(ring_ct)
    stereoct.append(stereo_cent)

# %% [markdown]
# New dataset with few features with SMILE strings

# %%
df = pd.DataFrame({'smiles': smiles, 'mole_logp': logp_ml,'tpsa': tpsa, 'mol_wt' : mol_wt,
                   'hbd': hbd, 'hba':hba, 'valencee':vale, 'max_partialcharge':partialcg_max, 'min_partialcharge':partialcg_min,
                   'rotatablebd':rotbd, 'ringct':ringct, 'stereocent': stereoct, 'dipole_moment':mu})

# %%
df
# Out:
#                    smiles  mole_logp   tpsa      mol_wt  hbd  hba valencee  \
# 0       CC(C1CC1)C1(C)CO1    1.82140  12.53  126.104465    0    1    (52,)
# 1           CC1C2OC1C2CCO    0.40210  29.46  128.083730    1    2    (52,)
# 2      CC12OC(=O)C1C1CC21    0.56780  26.30  124.052429    0    2    (48,)
# 3      OC12CC(C1)N(C2)C=O   -0.64810  40.54  127.063329    1    2    (50,)
# 4          C1CC2C3COC2C13    1.04120   9.23  110.073165    0    1    (44,)
# ...                   ...        ...    ...         ...  ...  ...      ...
# 4995  OCC12C3CC4C(C14)C23    0.49060  20.23  122.073165    1    1    (48,)
# 4996         CC#CC1CC=CC1    1.97590   0.00  106.078250    0    0    (42,)
# 4997         CCCC(CO)CC=O    0.98400  37.30  130.099380    1    2    (54,)
# 4998     CCC1=CNC(=O)C1=O   -0.02080  46.17  125.047678    1    2    (48,)
# 4999        CCCNC(=NC)C#N    0.53788  48.18  125.095297    1    2    (50,)
#
#       max_partialcharge  min_partialcharge  rotatablebd  ringct  stereocent  \
# 0              0.091610          -0.369601            2       2           2
# 1              0.068295          -0.396362            2       3           2
# 2              0.313390          -0.457792            0       3           4
# 3              0.209558          -0.387878            1       3           0
# 4              0.063829          -0.377307            0       5           2
# ...                 ...                ...          ...     ...         ...
# 4995           0.049544          -0.395765            1       5           6
# 4996           0.027117          -0.106418            0       1           0
# 4997           0.119854          -0.396074            5       0           1
# 4998           0.295518          -0.325333            1       1           0
# 4999           0.200611          -0.361550            2       0           0
#
#       dipole_moment
# 0            1.7117
# 1            1.6775
# 2            4.4194
# 3            3.4529
# 4            1.6540
# ...             ...
# 4995         1.5854
# 4996         0.1660
# 4997         3.1034
# 4998         5.4996
# 4999         3.2024
#
# [5000 rows x 13 columns]

# %%
df.tail(5)
# Out:
#                    smiles  mole_logp   tpsa      mol_wt  hbd  hba valencee  \
# 4995  OCC12C3CC4C(C14)C23    0.49060  20.23  122.073165    1    1    (48,)
# 4996         CC#CC1CC=CC1    1.97590   0.00  106.078250    0    0    (42,)
# 4997         CCCC(CO)CC=O    0.98400  37.30  130.099380    1    2    (54,)
# 4998     CCC1=CNC(=O)C1=O   -0.02080  46.17  125.047678    1    2    (48,)
# 4999        CCCNC(=NC)C#N    0.53788  48.18  125.095297    1    2    (50,)
#
#       max_partialcharge  min_partialcharge  rotatablebd  ringct  stereocent  \
# 4995           0.049544          -0.395765            1       5           6
# 4996           0.027117          -0.106418            0       1           0
# 4997           0.119854          -0.396074            5       0           1
# 4998           0.295518          -0.325333            1       1           0
# 4999           0.200611          -0.361550            2       0           0
#
#       dipole_moment
# 4995         1.5854
# 4996         0.1660
# 4997         3.1034
# 4998         5.4996
# 4999         3.2024

# %% [markdown]
# Convert SMILEs to SELFIEs

# %%
smiles
# Out:
# ['CC(C1CC1)C1(C)CO1',
#  'CC1C2OC1C2CCO',
#  'CC12OC(=O)C1C1CC21',
#  'OC12CC(C1)N(C2)C=O',
#  'C1CC2C3COC2C13',
#  'CN1C2CC2C1C#N',
#  'CN1C=C2ON=NC2=C1',
#  'COC1=CC=CC=C1',
#  'CCC1CNC(C=O)=N1',
#  'OCC(=O)N1CCC1=N',
#  'C1OC2C3C4C1C2CN34',
#  'OCC1OCC(O1)C=O',
#  'CCCC1CC(O1)C=O',
#  'C1C2C=CC(C12)N1CC1',
#  'CN1N=NC(O)=C1N',
#  'CC(C)C1CC1C',
#  'CCC(C)(O)C(O)C=O',
#  'CN1CC1C(=O)CC#N',
#  'CC12CN1C1C(O)C21',
#  'C1CC11CC2CC1C=C2',
#  'NC1=C(OC(=N)N1)C#C',
#  'CC1=C(C)C(N)=CO1',
#  'CC1CC2(C)NC2C1=O',
#  'CC1CCCC1(C)C',
#  'O=C1CC2OC3COC123',
#  'COC1(C)CCC1(C)C',
#  'CN1C(=O)OC(N)=C1O',
#  'CC1=NOC(=O)C(=O)O1',
#  'O=CC12CCC1C(=O)O2',
#  'CCOC12CC3OC1C23',
#  'CC(C)C12CC(C1)C2O',
#  'CCC1NC(C#N)C1O',
#  'CC1=CC(=CO1)C1CO1',
#  'O=CN(C=O)C(=O)C#C',
#  'CC(C)N1CC1CC#N',
#  'CC(C#N)C1=CNC=N1',
#  'COCC1C(C)OC1C',
#  'C1CC2C1C21CC2OC12',
#  'CC1=CC2CC(O)C1C2',
#  'CCCC12CC1OC2=O',
#  'CC(O)CC1COC1=O',
#  'CC1=CCC2(CO)CC12',
#  'O=CN1C=CN=C1',
#  'CC(C)C1C2C3OC3C12',
#  'COC=NC1=CN=NO1',
#  'C1OC=NCC2NC12',
#  'CN1C=NC(C#C)=C1N',
#  'O=CCC1=NC=CN=C1',
#  'ON=C1C2CN3CC1C23',
#  'CC1C=CC2C(C=O)C12',
#  'CCC1N=CN(C)C1=O',
#  'OCC(O)COCC#C',
#  'CN(C=N)C(=O)NC=O',
#  'OC1CC1N(C=O)C=O',
#  'CC1CCCOCC1O',
#  'CC1CNC1(C=O)C#N',
#  'OCCC1(O)C2CC1C2',
#  'COC12C=CC3CC1C23',
#  'NC1=NCCOC1=O',
#  'CC1CCC2C(C#C)C12',
#  'CC12NCC1C2(N)C#N',
#  'CC#CC1(C)OC1C',
#  'OC1C2COCC12C=O',
#  'N=C1CN=C2NCC2O1',
#  'CC1NC11COC1C',
#  'CN(C)C1=C(O)NN=N1',
#  'CCC#CCC1COC1',
#  'O=CC1C2CCC2C1=O',
#  'CC12CC1CCC2C=O',
#  'CC1=C(C)C2CC1C2=O',
#  'CC12OCC11CC2CO1',
#  'C#CC1CC2C3CC3C12',
#  'CC1(C)OC11CCC1O',
#  'CC(CO)CC(O)C=O',
#  'CN=COCCC#N',
#  'CC1C2CC(OC=N)C12',
#  'N=C1OC=NN1C1CC1',
#  'O=C1CN=CNC(=O)C1',
#  'O=C1C2C3NC(=O)N1C23',
#  'CC1NC1C1OC1C=O',
#  'O=CNC1=NCC2CC12',
#  'CCC1CC11OC2CC12',
#  'CC(C)(C#C)C(N)C#N',
#  'CCC1CC(C)=CCO1',
#  'N#CC12NC1C1NC21',
#  'CC(O)C1=NC=CN1',
#  'COC1C(C)CC1C#C',
#  'CCC12CCN1C2CO',
#  'NC1=C(F)N=CNC1=N',
#  'COCC1=CC=C(N)N1',
#  'CC1CC2(CC2)C(=O)N1',
#  'C#CCC1CC2CC1C2',
#  'OC1C2NC1C(C=O)=C2',
#  'CC(NC(C)=O)C#N',
#  'CC12OC1CC2(C)C=O',
#  'COCCN1CC1C',
#  'CC1OC11CC=CC1=O',
#  'CC#CC(CC#C)C#N',
#  'OC1=CNC2=C1N=NN2',
#  'C#CC1(CCC1)C#C',
#  'CC1=C(C)C(=O)ON=C1',
#  'CN1N=NC2=CNN=C12',
#  'C1NC2=CN=NN2C=C1',
#  'NC1=NC2=NON=C2N1',
#  'CC12C3C1C1=CC3CC21',
#  'OCCC(C=O)N1CC1',
#  'CC(C(O)C=O)N1CC1',
#  'CC1([NH3+])CCC1C([O-])=O',
#  'CC1(COC1C#C)C#C',
#  'CCC(C#C)C(O)CO',
#  'CC1OC(=O)OC11CC1',
#  'O=CCOCC#N',
#  'OCC1OCC1NC=O',
#  'CC1(CC1)C(=O)CCO',
#  'C#CC1CC(N1)C#N',
#  'CC12CN1CC2OC=N',
#  'CC1OC(=O)C1N(C)C',
#  'C1NC1C1C2C3CC3N12',
#  'CC1(CCO1)C1CO1',
#  'COC1CC(CC=O)C1',
#  'CC12C3CCC(C1O)N23',
#  'OC(C#N)C12CC(C1)O2',
#  'CN1CC1C1(CO1)C=O',
#  'CC(=O)C1OC1C1CC1',
#  'CC12C3OC3C1N2C=O',
#  'CC1CN2C1C(O)C2=N',
#  'OCCC1CN1CCO',
#  'CC1NC(=O)N2CCC12',
#  'CC1OCC=C2COC12',
#  'C1CC11OC2C3OC2C13',
#  'CC#CC1NC1C(C)O',
#  'CC1(O)C2COC12',
#  'CC#CCC(C)(O)C=O',
#  'COC1=C(N)OC(=O)O1',
#  'CC(=N)OC1CC1O',
#  'CC1C2CC(C2)C1=NO',
#  'COC(C#N)C(C)C',
#  'OCC1N2CC1(C2)C#N',
#  'O=C(C#C)C1=CNCC1',
#  'CC1CC2(CCC2)C1=O',
#  'CC1=NC=C(O)N=C1F',
#  'O=C1C=CC2CC3C2C13',
#  'CC(COC=O)CC=O',
#  'OC1C2CCC(O)C12',
#  'C#CCC1OCC1C#C',
#  'CC(=O)C(C#C)C1CO1',
#  'CC1C2C3OC1C=CC23',
#  'CCC1OCOC1CC',
#  'OC1C2C3C1N=CN23',
#  'OCC1NC1CO',
#  'N#CC1C2C3OC1C23',
#  'CC(O)C(CO)C#C',
#  'O=C1CNC1CCC#C',
#  'CC1C(C)C2(C)CC12C',
#  'C1CC2C3OC=NC2C13',
#  'CN1C2CCC(C)(C)C12',
#  'OCCOC1=CN=NO1',
#  'CC1CCC1OCCO',
#  'CCN1C=CC(NC)=C1',
#  'COC12CC1(NC2)C#C',
#  'COC=NCCCCO',
#  'CC12C3CN(C13)C2C=O',
#  'N#CC12CCC3CC1C23',
#  'CCCC1=NOC=C1C',
#  'O=C1CC2NC3CNC123',
#  'OC(C#C)C1=NON=C1',
#  'CC1=C(N)CNCC1=O',
#  'CC1=C(C)C(=O)C=NO1',
#  'C1C23COC12C=CCC3',
#  'CC1CC2(CO)CC12C',
#  'O=C1CC2C3C(CN23)O1',
#  'C1CC2CCCCC12',
#  'OCC#CCN1CCC1',
#  'C1NC2=C(C=C1)N=NN2',
#  'CC1C2OC1C(=O)C2O',
#  'C1C2C=C3CN4C1C2C34',
#  'CNC1=NNC(N)=C1N',
#  'NCC(NC=O)C#N',
#  'CC(=O)C1C2CC=CC12',
#  'O=C1CC2(CN2)CO1',
#  'CC1=COC2=C1OCO2',
#  'C1CC23OC4C2C=C1C34',
#  'CC1C2CC(O2)C1=NO',
#  'CC(C#N)C(C)(O)CO',
#  'CC1OC1C(=O)OC=N',
#  'CC1=C(N=NO1)C1CC1',
#  'OC12CCC1OCC=C2',
#  'O=C1NC2C(C#C)C12',
#  'CCC1CC(C)(O)C1C',
#  'CC1C2CC2NC1=O',
#  'C1C2OC11CCCC21',
#  'C1CC1OC1C2CCC12',
#  'FC1=NNC(=N)NC1=N',
#  'COC=NC1(C)CC1O',
#  'CC#CC(C#C)C#C',
#  'CN1N=C(C)C(O)=N1',
#  'OC1C2CC2C11CC1',
#  'CC1CC2(CC#N)OC12',
#  'OC1CC23COCC12O3',
#  'CC12CC(O)C1OCC2',
#  'CC1(N)CN(C=O)C1=O',
#  'COC1COC1=O',
#  'C1C2N3C1C21OCCC31',
#  'OC1CCCC2CC1C2',
#  'COC1=NC(O)=CN1C',
#  'OCCC1COC1C#C',
#  'CNC(=O)OC1(C)CC1',
#  'C1N=COC2=CON=C12',
#  'CCC1(CC(=N)O1)C#C',
#  'CC(O)C1CCC(=N)O1',
#  'CC12C3CC1CC2(O)C3',
#  'NC1=NC2CCC2O1',
#  'CCCCC1CC1O',
#  'CC12C3C4C3C1(C)N24',
#  'ON=C1C2CN3C2CC13',
#  'CC12COC1COC2=O',
#  'CC1C2C3N(C)C2C13C',
#  'OCC1=CNN=CC1=N',
#  'O=C1OCC2C3CN2C13',
#  'N=C1NC2=C(N1)C=CO2',
#  'OC1=NC=NN1CC#C',
#  'CC(=O)C1=NOC(C)=C1',
#  'CC1(C)CCOCC1',
#  'NC(=O)C1CN1CC=O',
#  'CC12CC1OCCCC2',
#  'CC1OC1CC1CCO1',
#  'CN=C1OCC1N',
#  'COC(=N)CCO',
#  'CCC1(C#N)C(C)N1C',
#  'CCC1=CC(C)(C)CC1',
#  'O=C1CC=C2CCC2C1',
#  'CC1OCC1CC#N',
#  'O=CC1=CC2(CC2)CC1',
#  'CC1C(O)C1OC=O',
#  'CC1C2CN3C2C13C=O',
#  'CCN=C1OCC1C=O',
#  'CC1NCC(=O)C1O',
#  'CC(=O)C1CCC1C#N',
#  'C#CC12NC1CC21CC1',
#  'CC1C(O)C2OC12C#C',
#  'COC1C2CC1N1CC21',
#  'CC1CC2C=CC(O)C12',
#  'CC(C#N)C1OCCO1',
#  'OC1C(O)C2=CCOC12',
#  'CC12CC1(O)CC2',
#  'COC(=O)C1NC1CO',
#  'CC1CC(C#N)C2CC12',
#  'CC1=NN=C2NN=CN12',
#  'COCC(O)CC#C',
#  'CC(C)(C#C)C1(C)CC1',
#  'NC1=CC(=O)O[C-]1C[NH3+]',
#  'CC1=CCCOC(=O)C1',
#  'C1N2C3C4OCCC13C24',
#  'CC1(C)C2CC1C21CO1',
#  'OC1(C=O)C2CN2C1=N',
#  'CC1C2CC(C)=CC1O2',
#  'CC(C)C1(O)C2CCC12',
#  'NC(=O)COCC(N)=O',
#  'CC1(CO1)C1=CCOC1',
#  'C1NC1C#CC1COC1',
#  'CC1(CO)CCCO1',
#  'COC1C(C)COC1=N',
#  'CCC1C(O)CCC1=O',
#  'CC(C)N1CCOC1=O',
#  'C1C2CCCCCCC12',
#  'OCC1(O)C2CCC1O2',
#  'N=COCC1(CO1)C#C',
#  'CC1OC(C)(C)C=C1C',
#  'NCC(N)(CCO)C#N',
#  'CCC(O)C1(C)CC1O',
#  'OCC1C2CC1(O)CC2',
#  'N#CC1C2OC3C2OC13',
#  'CC1(CC1)OCCC#C',
#  'CC1(CO)OCC2NC12',
#  'CC1=CC(=O)NC1=N',
#  'CC1OC(C#N)C1C#C',
#  'OC1=CNC(F)=CC1=N',
#  'CC(C#N)C#CCC#N',
#  'CCCC1C2CC(=O)C12',
#  'NC1=C(C#N)C(O)=NO1',
#  'CCCC1(C)NC1C#C',
#  'CN1C(=N)NN=CC1=O',
#  'CC1(CCCO)COC1',
#  'N=CNC1=COC(=O)O1',
#  'C1CC(C1)C1CC=CC1',
#  'NC1=CC(=O)C(O)=NO1',
#  'CC12C3N=CN1CC23O',
#  'OC1CC2(CC1O2)C=O',
#  'O=C1NC=CO1',
#  'OC1CCC(CC1)C#C',
#  'C1C2C3C=CC1C23',
#  'CC12CN(C1)CC(=O)C2',
#  'NC1=NN2C=NN=C2N1',
#  'NC(=O)N1C2CC(=O)C12',
#  'C1CC23OCC4C2CC134',
#  'OC1C2CC2CC11CC1',
#  'CC1(CC#C)CC1O',
#  'OC1(C#C)C2OC=NC12',
#  'CC1OC2CC12C1CO1',
#  'CC(C)OC(=O)C1CO1',
#  'CC12CC1CC(=C2)C#C',
#  'CN1C(C(N)=O)C1(C)C',
#  'O=C1CC=C2C3CC3N12',
#  'CCOC1CC1C#CC',
#  'CC(N(C)C=O)C(N)=O',
#  'CNC1=NN(C)C(O)=C1',
#  'OCC1CCOC1C#N',
#  'CC1C(C)(C)C1(O)C#C',
#  'CC1CC(CO)OC1=N',
#  'OC1CN2N=CN=C12',
#  'CC#CC12CC1C(=N)O2',
#  'OC1=CC=NOC1=N',
#  'OC1CC(C1)OCC#C',
#  'CCN1C=C(O)C=C1N',
#  'CC1CC(C)(C1)C(C)=O',
#  'NC1=CC(=O)N2CC2C1',
#  'CC12CC1C1OCC21C',
#  'COCC(O)CC(C)O',
#  'OCC1=C(ON=N1)C=O',
#  'C1C2OC3CC12OCC3',
#  'CN1N=CC=C1N(=O)=O',
#  'CC1OC(=O)C(C)C1C',
#  'CN1C=NC2=C1CCO2',
#  'CC1N=COC2CC12O',
#  'CCN1C(C)C(O)C1=O',
#  'CC1OCOC11COC1',
#  'OCC1NC1CCC=O',
#  'CC1=CC2C3CC1CC23',
#  'CC1CC2(CC2O1)C#C',
#  'OCC12CC3CC1N23',
#  'CNC1=NC=CC(O)=N1',
#  'C#CC1=CC2CN3C2C13',
#  'NC1=CC=CN1CC#N',
#  'CCC12NC1(C)C1CC21',
#  'CC1(C)CC=CC2NC12',
#  'CC(=O)CC1CO1',
#  'CC1C2CC1C1CC21',
#  'CCC(=NO)C1(C)CO1',
#  'OC12CC3C1NC23C=O',
#  'N#CC12CN3CC3C1N2',
#  'CC1C=C(C=O)C2OC12',
#  'C#CCNC1=NC=NO1',
#  'ON=C1CC(O)C2CC12',
#  'CC12CC1C1CC2O1',
#  'C1NCC2=C1ON=N2',
#  'NC1=CC=C(N)N1C=O',
#  'CC12CC3C1OC2C3O',
#  'CCOC(=N)C(O)CO',
#  'CCC1CCC(O)C1C',
#  'CC1CC1CNC(C)=O',
#  'CC1C2C(=O)CC12C#N',
#  'N#CC12CC3C1C1C2N31',
#  'CC(C#C)N1C=CC=N1',
#  'COC1OC2CC1C2C',
#  'CC1(CO)CNC(=O)O1',
#  'COC1CN=C(O1)C#C',
#  'OC1C2OCC3(CO3)C12',
#  'N=C1CC2=C(O1)N=NO2',
#  'CC(NCC=O)C(C)=O',
#  'O=C1NCC11NC1C#N',
#  'CC1C2COC11COC21',
#  'OC1C2C(C#N)N2C1=O',
#  'CCC(O)C(C)CCO',
#  'CC1CC2COC12C#N',
#  'CC1OCC2C1CC2=O',
#  'OC(C#C)C1=NCCO1',
#  'CCC(CCC#N)=NO',
#  'NC1COC1=NC1CC1',
#  'O=CC(=O)NCCC#C',
#  'CC1CC23CC4N2CC134',
#  'COCC1(CO1)C#N',
#  'CCC(=O)C(C)(C)O',
#  'O=CC1CCOC1',
#  'N#CC1CN1CC1CO1',
#  'N=C1OC=CC(C=O)=N1',
#  'COCC(C)C(C)C#C',
#  'O1C=C2C=NC=C2N=N1',
#  'CC1C2C3C2N2C3C12C',
#  'CC1C2OCOC(=O)C12',
#  'OCCC(O)C#N',
#  'CCC12CC(C)C1C2C',
#  'O=C1CC=C2CC=CC12',
#  'COCCC1CCCO1',
#  'CCCNC(=O)CCC',
#  'OC1C=CC2(O)COC12',
#  'CC12CC(C1O)C21CO1',
#  'ON=C1CC(O)C11CO1',
#  'O=CCC1=CCCC1=O',
#  'CCNC1=CON=C1O',
#  'O=C1C2OCC3C2N13',
#  'CCC(=O)OCCC#N',
#  'NC(=O)OCC(O)CO',
#  'OCC1C2CC1(O)C=C2',
#  'OCC1C2C3CN3C12',
#  'C#CC1NCC2CC1O2',
#  'C1CC11C2C3C=CC2C13',
#  'N=C1NN=C(NC=O)O1',
#  'CC1(COC(=O)O1)C=O',
#  'CCC1=CC(C)(C)OC1',
#  'CC1(C#C)C2C3CC2N13',
#  'N#CC12CC=CC1O2',
#  'CC1CC2C3OC2C3C1',
#  'OC1CC2NC2(C1)C#N',
#  'NC1=CC=CN1',
#  'C#CC12OC3C1NC23',
#  'CN1CCC1C(=O)C#C',
#  'COC1COC1',
#  'CC(=O)COC(=O)C=O',
#  'CCOC12CC(C1)C2=O',
#  'COCC(CO)CC=O',
#  'N#CC1CC2=CCOC12',
#  'CCC(=O)OCC#CC',
#  'CC1NC(=O)C2CC12C',
#  'CN1CC11C2CC2C1O',
#  'CC1CC1(O)C#CCO',
#  'CC1=C(N)OC=C1N',
#  'CC(O)(CNC=O)C#C',
#  'CC1C(C)N1C=O',
#  'CC(CO)N1N=CN=N1',
#  'C1OC23C1CC21CC3O1',
#  'C#CC1C=CC2OCC12',
#  'OCC1C2CC3C2N13',
#  'COC1=NC(O)=NO1',
#  'CC1=C(C=O)C(=O)CC1',
#  'CC12CC3N1CC23C#C',
#  'C#CC1NC1C1CO1',
#  'OC1C2C3C(C=O)C2C13',
#  'CC1=CNCCC1=NO',
#  'ON=C1C2CC1(N2)C#N',
#  'CC1C2COC1COC2',
#  'FC1=NC(C=O)=NC=C1',
#  'CC1=CC(=O)C(CO)C1',
#  '[O-]C(=O)C1[NH2+]CC11CC1',
#  'COC1(CC1CO)C=O',
#  'CCC#CCCC#N',
#  'CC1=NNN=CC1=NO',
#  'CC1C2OC2C1C(C)=O',
#  'CC1=CN2CCC2=C1O',
#  'CN1C=C(OC1=N)C#N',
#  'O=C1CCC2CC2C1',
#  'CN=C1OC2C3OC1C23',
#  'CN(CC=O)C(N)=O',
#  'CC1OC2CC3C2CC13',
#  'C#CC12C3C4CC1N2C34',
#  'CC(C)(CC=O)C1CC1',
#  'CC1=CC(CO)C(=O)N1',
#  'CC12COC1CN2C=O',
#  'CCC#CCO',
#  'O=C(OC1CCC1)C#N',
#  'CC(=O)C(=O)C(=O)C=O',
#  'CC12COC3CC1C23',
#  'CN(C(N)=O)C(=N)C=O',
#  'CC1(C2CO2)C2CCN12',
#  'N#CCC1=NC=CN1',
#  'OC1CCC2(O)CC12',
#  'CCC(=O)C1OCC=C1',
#  'C1CC2CC=CCC1O2',
#  'C1CC23OC4C2C1C34',
#  'CCC1(C)COC1=NC',
#  'CC1C2NC2C2(C)OC12',
#  'COC12CC3C1C3(C)C2',
#  'CC1CC2(O)C3CC2N13',
#  'CC1CCC2(CN12)C=O',
#  'CC1OC(C)C1O',
#  'CC12CN1C=NCC2=O',
#  'O=C1OC2CC1N=CO2',
#  'COC1=NNC(=N)N1C',
#  'O=C1CCC=CN1',
#  'NC(=O)COC(=N)C=O',
#  'CCC1CC=C(C)C1O',
#  'CC1=CC2NC2C(O)C1',
#  'CC#CC(O)C(C)(C)O',
#  'COC(=O)CCC(C)=O',
#  'N=CN1CC1(C=O)C#C',
#  'C1C2CC3CC3C12',
#  'CC(CO)(CC#C)C#N',
#  'OCCC(=O)C=O',
#  'CCN(CC#C)C(N)=O',
#  'CC1=CC=C2C3CC3N12',
#  'NC(=O)C(CC=O)C=O',
#  'CC1=CC(CC#N)=NN1',
#  'OC1C2C3CN4C1C2C34',
#  'OC1C2C(=N)OCC12O',
#  'OCC1(CN1)C1CN1',
#  'OC1COCCC11CO1',
#  'OC1(C=O)C2CCC12',
#  'OC1C2C1C1CCC2O1',
#  'CCN1CC23CC(O2)C13',
#  'O=C1C=CCN2CC1C2',
#  'CC1(C2CCN12)C(N)=O',
#  'OC1CCC2C3CC1N23',
#  'C#CC(C#C)(C#C)C#C',
#  'CC(=O)OC=NC1CC1',
#  'CCCN(C)C(=O)CO',
#  'CC1(CC2(O)CC12)C#C',
#  'CC1(COC1=N)C#C',
#  'N#CC12CC3COC1C23',
#  'CN(C)CC(=O)C=O',
#  'CC1(CN1CCO)C=O',
#  'CC1C(CCO)C1(C)C',
#  'C1C2CC3CC2C1OC3',
#  'CC1(C)CCC2CN2C1',
#  'CC1CC(C1)C#CCO',
#  'CC(C)(C)C1CC1CO',
#  'O=CC1(CCCN1)C#N',
#  'N=C1C2OC2C2CN12',
#  'CC1NC1C1(O)COC1',
#  'OC12C3N=C4OC(C13)C24',
#  'N#CCC12OC1C1NC21',
#  'CC(C)(C)C(C=O)C#N',
#  'CCCC1(CC1O)C=O',
#  'CCC1=CC(=CO1)C#N',
#  'CC1NCC2=C1N=CO2',
#  'C1CN2CC3OC3C12',
#  'NC1=C(C#C)C(O)=NN1',
#  'N#CC1CNC1C1CN1',
#  'CC(C)CN(C)C(N)=O',
#  'CC(C=O)N1CCC1',
#  'CC(CO)(C=O)C=O',
#  'C1CC23OC4(COC24)C13',
#  'C1CC1C1C2COCC12',
#  'CNC(C#N)C1OC1C',
#  'COCC1(C)NC1C#N',
#  'OCC12CCCC1N2',
#  'COC1CN(C)C(=O)C1',
#  'NC1=NC(CC1=O)C#N',
#  'COCC1(O)COC1=O',
#  'CC12OCOC1C2C#C',
#  'CC1C2CC2C1NC=O',
#  'CC1CC2OC2C=C1',
#  'OCC1OC1C1COC1',
#  'OCC1=CN=NC=N1',
#  'OC1C2OC1(C#C)C2=O',
#  'O=C1COC2=CN=CN12',
#  'CCC1(C)C(O)C1CO',
#  'OC1COC2C3OC1C23',
#  'C1C2OC3C=CC1C3O2',
#  'CC1CCOC2CC2C1',
#  'CC(O)CN1C(C)C1C',
#  'CCOC1C2OC(=N)C12',
#  'O=C1CC=CC11CCC1',
#  'CC1C2OC(=O)C12',
#  'C1CC23NC4C2NC34C1',
#  'COC1CCOC1=N',
#  'C#CC1C2C3CC=C1C23',
#  'N=C1OC=CC=C1C=O',
#  'C#CC12CCC(CO1)C2',
#  'NC1=CC(=O)CC1',
#  'OCCC12CC(O)(C1)C2',
#  'COC1CCCOC1=N',
#  '[NH3+]CC1=C([O-])NC(=O)O1',
#  'O=C1C2NC2C2CC1C2',
#  'CC12OC(=N)C1N1CC21',
#  'FC(F)(F)C12CN(C1)C2',
#  'CC(C#N)C1(CC1)C#N',
#  'N#CC1CCC=CCN1',
#  'CCCC1N=CNC1=N',
#  'CC1C2C3CCC1(O)C23',
#  'CN1CCOCCC1=O',
#  'OC1CC2(CC3OC23)C1',
#  'CCN1CC1(C)C=O',
#  'COC1C2OC1(C)C2C',
#  'CCC1=CC(O)=NN1C',
#  'CN=C1NC2(CC2)C1O',
#  'CCCOC(N)=O',
#  'C1CC2=C(C1)C=NN2',
#  'C(OC1CC1)C1CO1',
#  'OC1C2CC(CC12)C#N',
#  'CCC1(CC1)OC(C)C',
#  'CN(C(N)=O)C(=O)C#C',
#  'CC(=O)CC1(C)CC1',
#  'CCC12CC3C1N3C2',
#  'OC12CC(C1)C21CC1',
#  'CC12C=CCCC1C2O',
#  'CC1COCC1(N)C#N',
#  'CCC12CC1(CC2)C=O',
#  'OC1CC11CC(O)C1',
#  'OCC12CC(O)(C1)CC2',
#  'C#CCCC#CCC#C',
#  'C1C2OC3CC1CC23',
#  'COC1(C)C2CCC12',
#  'NC(=[NH2+])O[C-](C#N)C#N',
#  'CC1=C(C)C(=N)OC1',
#  'CC1=C(NC=O)C=NO1',
#  'CC12CC(=O)N1C=NC2',
#  'OCC(O)C1OC1CO',
#  'CC(O)CC1CC1CO',
#  'CC([NH3+])(C1CN1)C([O-])=O',
#  'CN=C1OC(=O)CC1O',
#  'CN=COCCCC#C',
#  'CC1(C)NC1C(=O)C#C',
#  'CC1=NC(=N)N=CN1',
#  'COC(=O)C1CO1',
#  'O=CCN1C=CN=C1',
#  'C1CN1C1=NC=CN=N1',
#  'CC(C)C1=CNC=C1',
#  'CC1CC2CC2C1CO',
#  'COCC1C2C=CC1C2',
#  'O=CN1C2C3N4C3C1C24',
#  'CC1C2C3CC2(CO)N13',
#  'NC1=CN=C(O1)N(=O)=O',
#  'CC1CC=CC1CC=O',
#  'CC1C2C=CCCC12C',
#  'CC12C3C4C1C=CC2N34',
#  'COCC1C2CC3C2N13',
#  'O1N=NC2=CC=CC2=N1',
#  'N=COC1=NC=NC=C1',
#  'CCC(C)CC#N',
#  'CC1C(O)C2OC12CO',
#  'COC(=O)C#CC(C)C',
#  'CC(C)C1NC1C1CO1',
#  'OC1C=CC(O)C1C#N',
#  'CN1C2C=CCC12C#N',
#  'OCC1C2C3CC1OC23',
#  'CC(CC1CC1)C=O',
#  'OC12CCC11CCN1C2',
#  'C#CC1=CC2CC(C2)C1',
#  'CC1OC(=N)OC1CO',
#  'OCC1(O)C=CCC1=O',
#  'CC1(CC2CC1O2)C#N',
#  'NC1=C(NN=C1)N(=O)=O',
#  'O=C1N=CC=NC=N1',
#  'OC1C2NC1(C#C)C2=O',
#  'CC1=NC=C(N)N=C1N',
#  'CCC1(C)COC(C)O1',
#  'OC1C2NC2C2(O)CC12',
#  'O=C1NCC11CC1',
#  'CCC(C)OCCC#C',
#  'CCCCC1=NOC=N1',
#  'CC(C=O)N1C=NN=N1',
#  'OC1C2OCC1N=CO2',
#  'OCC12CN1CC2O',
#  '[NH3+]C1(CC1)C1=N[N-]N=N1',
#  'CC1C2CCC1CC2',
#  'CC(CC#C)C1CC1O',
#  'CC(C)(O)C1CC1O',
#  'CC1C=C(C)C(O)C1=O',
#  'CC(=O)CN1CCC1=O',
#  'CC1OCC1NC(N)=O',
#  'C1C2CCC3OCOC123',
#  'CN(CC#C)C=O',
#  'CC1OC1(C)C(O)C=O',
#  'O=CCC1OCC2CC12',
#  'CC(C)N(C)C=O',
#  'CCC(C)C(NC)C#N',
#  'CC1(C)CC(O)C2CN12',
#  'OCC1=CC(=O)OC=N1',
#  'CCOC=NCC',
#  'CC1(C#C)C2C3CC1C23',
#  'CCC1NC11COC1=N',
#  'C#CC1=NC=NC=N1',
#  'OCCC12OC1CC2O',
#  'CC1=NN2CCC2=C1',
#  'CC1COC2CC(C2)O1',
#  'CC1(CCCC#C)CC1',
#  'COCCC1OC1C=O',
#  'CCCC1CCC(C)=C1',
#  'OCC1=CCCC11CN1',
#  'CC(=O)N1CC1C#N',
#  'CC1(CC1NC=O)C=O',
#  'CC1OC2CN3C1C23C',
#  'CC(=N)OC(CN)C#N',
#  'CC12C3C4C(C4C1O)C23',
#  'N=CN1C=NCCC1=O',
#  'CC(C)C1=COC(C)=N1',
#  'O=C1CC2CCC(C2)O1',
#  'CC1OC2(C)C1CC2=O',
#  'C1CC2(CCOC2)O1',
#  'CC(CO)N1CC1C=O',
#  'CC(O)CC(=O)C(C)O',
#  'C1CC23NC2CC2C3N12',
#  'COC1=NNC(C)=C1',
#  'OC1C2C=CC11CCC21',
#  'O=CC12OCC1N1CC21',
#  'NC1=C2CCNC2=NO1',
#  'OCCNC(=O)C1CC1',
#  'CC1CNC(=N)C(=O)C1',
#  'C1C2C3C1N1CC3=CC21',
#  'CC1CC=C(C1)C1CO1',
#  'NC1=C2CC=CC2=CN1',
#  'CN1N=C(N)C=C1C#C',
#  'CC1OC1(C)C1CN1C',
#  'CCOC12CC3C1CC23',
#  'CCCC1CCC2CC12',
#  'OC1=CC=NC=CC1=O',
#  'C1CC2C3NC3C2O1',
#  'CCCOC(=O)C1CO1',
#  'O=C1C2CCN2C1C#N',
#  'O=CC1CC(=O)OC=N1',
#  'O=CCCC1C2CCC12',
#  'CN1C(CO)CCC1=O',
#  'CC1(C)C2OC(C#C)C12',
#  'CC1CC23CC(C2)CC13',
#  'CC1(CNC1=O)C=O',
#  'CN1C=NC(CO)C1=N',
#  'CCC1=NNC(=N)C=N1',
#  'CC1=COC(NC=O)=N1',
#  'CC1(C)OC2(C)CCC12',
#  'OCC(C#C)C1CO1',
#  'CC(C#C)C1=COC=N1',
#  'CC1CCCC1(O)C#C',
#  'CC(C#C)C1=CNN=C1',
#  'CC1C(O)C1C(O)CO',
#  'OC12CC1C1(CO1)C2',
#  'CC(C=O)C1=NON=N1',
#  'CCOC1CCOC1=N',
#  'CC(C)C1=CN=NN=N1',
#  'COC(=N)N1CCC1=O',
#  'CC(=O)C1=CNC(=N)O1',
#  'CC1OC1C#CCCO',
#  'C1C23COCOC12CO3',
#  'CC1CC2C3CC2C1O3',
#  'N#CC1NC2CC1C2',
#  'CC1(CC(=N)O1)C=O',
#  'OC1(C#N)C2COC12',
#  'CC1NC(C)C(=O)C=C1',
#  'CC12CC=CC1C2C=O',
#  'CC1(C#C)C2NC1C2O',
#  'NC1=CN=C(N)C=N1',
#  'NC(=O)NC1C2COC12',
#  'CC1(O)C=CCC1C#C',
#  'C1CC2=C(CO1)C=NN2',
#  'CCOC(=N)C#C',
#  'CC12CN1C1(CO)CC21',
#  'OCC1=NC=CNC1=O',
#  'CCC1=CC(=O)C2CC12',
#  'CCC1OCC11CO1',
#  'C1OC2C3CN4CC3C124',
#  'CC1CC2NC2C1C=O',
#  'CC1C(C)C1(C=O)C#N',
#  'CCC(CC)C(C)(C)O',
#  'OCCC1CC(O)C1',
#  'OC1CC2COC2C1O',
#  'NC1=NC2=C(O1)C=NN2',
#  'O=COC1=NC=CC=C1',
#  'CNC1=C(CO)N=NO1',
#  'N1N=CC2=CN=CC2=N1',
#  'COC1CN2CC(C)C12',
#  'O=C1C2CC(N2)C1C#N',
#  'CC1=CC(=O)CC1(C)C',
#  'CC1CCOC(C)C1O',
#  'CC12CC(C)(O1)C1CC21',
#  'CC1OC2C1C2(C)C=O',
#  'CC(=N)NC1=CC=NO1',
#  'CC(NC1CC1O)C#N',
#  'CC(C=O)C(C=O)C#C',
#  'CC1CC2C3OC3CC12',
#  'COC1=C(N)NC=N1',
#  'CC12C3N=CN1C(=N)C23',
#  'CN=CNC1=CN=NO1',
#  'CC(C)OC1COC1C',
#  'CC1(CNC=O)CCC1',
#  'CC1=C(COC1)C#C',
#  'CC12CC1C1NC1CO2',
#  'CC1OC2C1C1CC21C',
#  'ON=C1C2CC1(O)CO2',
#  'CN1CCC=CC1C#N',
#  'CN1C2C3OC3C1C2=O',
#  'CC1CCC11CCC1O',
#  'CC1=C2CN3C2C3(C)C1',
#  'CC1(O)C2OCOC12',
#  'OCCC(=O)C(O)C=O',
#  'N=C1OCC2C3OC3C12',
#  'COCC(C#N)N1CC1',
#  'OC1=NOC2=C1CCN2',
#  'NC1(CCC2CC12)C#N',
#  'CNC1=CN(C)N=N1',
#  'O=CC1CC1CCC#N',
#  'O=C1CCN1CC1CC1',
#  'CC1(CC1)C1=NOC=N1',
#  'CC12NC1COC21CC1',
#  'C1CC1C1COC=N1',
#  'O=CC1C=CC2CN12',
#  'OC1C2C3NC2(C=O)C13',
#  'OCC(OC=N)C#N',
#  'CC1C(=O)OC11CCC1',
#  'CCC1CC2OCC2=C1',
#  'CC1=CC(C=O)C(=O)C1',
#  'CC(C)C1=CN=C(C)O1',
#  'CCCC12NC3C1OC23',
#  'CC(=O)N(CCO)C=N',
#  'CN1C2C3CC(O3)C12C',
#  'CC(CO)C1(CO)CO1',
#  'CNC(=O)NC1CC1C',
#  'CC#CCC1=NC=NO1',
#  'CC1C2CCC(C2)C1O',
#  'CCC(CC)C1OC1C',
#  'CCC1(CO1)C1(O)CC1',
#  'OCC1C2CCC12CO',
#  'C1COC2(C1)OCC=C2',
#  'CC12CC(C1)C(=O)C2',
#  'O=C1C2OC2C11CO1',
#  'CC(O)CCC(C)C=O',
#  'N#CC12CC=CC1CN2',
#  'C1NC1C1COCCO1',
#  '[NH3+]C1C[N-]C(=O)C1C#N',
#  'CC1CC(=O)C(C)(O)C1',
#  'N#CC1=CC=C(N1)C#N',
#  'COC(=N)C#CCCO',
#  'N#CC12C3OC1C=CC23',
#  'C#CC1(CCOC1)C#N',
#  'CN1C=CC(=O)CC1=O',
#  'ON=C1C(O)C2CC12O',
#  'CN=C1OC=CN=C1',
#  'CNC1=CC(=O)OCC1',
#  'CCC1=NNC(CO)=C1',
#  'OC1=NNC(OC=O)=C1',
#  'N#CCC12CN1CCC2',
#  'CN(C=N)C1=NON=N1',
#  'OC1C(O)C2OCC12',
#  'C1C2CC1C1CCC2C1',
#  'CN=COC(=O)NC=O',
#  'CC1(CO)CCC(=N)O1',
#  'CCC(O)CC(=N)OC',
#  'ON=C1CC=CCC=C1',
#  'CC1C(C)(O)C1(O)C#N',
#  'CC1=CC(O)C=CCC1',
#  'N#CC1=NCC2CCN12',
#  'N#CCCC1=NNC=C1',
#  'CC1=CC(C)(O)C2CC12',
#  'OC(C#C)C(O)C1CN1',
#  'CC12COC1C1CCC21',
#  'CC12OC1C(O)C2(C)O',
#  'CCC(C)(O)CC1CC1',
#  'COC(=O)C1(CC1)C#C',
#  'CC1NC11CCC11CO1',
#  'CC(C)COC(C)=O',
#  'O1C2C3C4C1C1C2C3N41',
#  'COC1C=C(C)CC1C',
#  'OCCC(=O)C1CC1',
#  'COC1CC2C(O)C12',
#  'CC(O)CC1CC(C)O1',
#  'CC(=NO)C1(CO)CN1',
#  'CC12CC1C(O)C1CN21',
#  'O=C1CCC2NC2C=C1',
#  'N=CNC(=O)CC1CO1',
#  'OC1C=CC(=O)C2CC12',
#  'OC1C2NC2C=CC1=O',
#  'COC(=O)N(C)C(C)=O',
#  'CCC1=C(OC)C=NO1',
#  'COC1(CC1)C(C)C#C',
#  'OCCC(O)C1CCO1',
#  'OC1CC1(C=O)C#N',
#  'O=CN1C2CC1C1CC21',
#  'OC1C2C3C1C(C#C)N23',
#  'C1C=CCC2=C1OC=N2',
#  'CCCCN=CNC=O',
#  'CC1=C(N)OC(O)=N1',
#  'OC1CC(=O)C1C#C',
#  'COC1C2CC1(C)C2C',
#  'N#CC1C2C3CCC2C13',
#  'OC1=CN=C(F)C=C1O',
#  'CC1CC(C)C1(C)C=O',
#  'C#CC1=CCC2(CC2)C1',
#  'CC(=O)C1=CC2CC1O2',
#  'C1CC1N=C1CCCO1',
#  'NC1=NOC(=C1)C#N',
#  'OCCC1C2C3NC3C12',
#  'CC1N2CC11OC(=O)C21',
#  'N#CCN1C=CC=N1',
#  'CN1C=C(CO)N=C1O',
#  'CN(C)C(=O)NC=N',
#  'O=CNCC(=O)C1CO1',
#  'CC1OCC2(CN2)C1O',
#  'NC1=NNC=C1OC=O',
#  'CC1OC11C=CCC1C',
#  'OCC(C#C)C(O)C=O',
#  'O=C1NC2CC2(N1)C#C',
#  'FC(F)(F)C1CCC=C1',
#  'OC1CCC11CCCO1',
#  'CC12C3CC1OCC2O3',
#  'CC1(C)CC2COC12C',
#  'CC1CCC([NH2+]1)C([O-])=O',
#  'O=CNC1=CC=NO1',
#  'COC1C2CC3CC3C12',
#  'N=C1CCCC(O1)C#C',
#  'O=C1C2C3C2C2C3N12',
#  'CC1CCC11CCC1C',
#  'C1C2CC1C1OC1CC2',
#  'CN1C2C3OC3C(O)C12',
#  'CC#CC1NC1C#CC',
#  'CC1=CC2CCC1(O)C2',
#  'COCC1(O)CCC1=O',
#  'OC1C2OC=NCC12O',
#  'CCC1(C)CC1(O)C#C',
#  'CNC1C(C)OC1C#N',
#  'CCC1=NOC(C=O)=C1',
#  'COC1C2CC1N2C',
#  'CC(O)CC1=CN=CN1',
#  'NC(=O)OC1C2CC1O2',
#  'CC1C2CC2C1(C)C#C',
#  'O=C1C2OCC3CN1C23',
#  'O=C1OC2OC1CC=C2',
#  'CNC(C)(C=O)C(N)=O',
#  'N=C1NN=CN1C=O',
#  'CC12CCC1CCCC2',
#  'OC12CC1OCOCC2',
#  'OC12CC(=O)C3C1NC23',
#  'N=CN(CC#C)C=O',
#  'OC1CC11C2OC1C2O',
#  'C1OC23CC(C2)C=CC13',
#  'OCC(C#C)C#CC#C',
#  'NC1=CC(CO)=NO1',
#  'O=C1CC2C3CC(C1)C23',
#  'O=C1CCC2CC3C2C13',
#  'NC1=C(N)C=C(N1)C#N',
#  'CCC1=C(N)C=C(N)N1',
#  'C1CC11C2CC3CC1N23',
#  'CC1CCC2C1CC2=O',
#  'CN1CC1CNCC#N',
#  'CC1CC2(CC2)C(=N)O1',
#  'OC12CC1(O)COCC2',
#  'CC12CC1CCC2=O',
#  'O=C1CN2CCC2CO1',
#  'N=C1OCC(C=C1)C#N',
#  'C#CC1OC1CC#N',
#  'C1CC(O1)C1COC1',
#  'CC12COCCCC1N2',
#  'CC(C)C(O)C(C)(C)O',
#  'O=C1OCC2=CCCC12',
#  'CCC1=NCC(O1)C#C',
#  'CC(C)N1N=NC=C1C',
#  'OC1=NC(=O)NC=C1',
#  'CCCCNC(=O)NC',
#  'O=CC1CC2CCC1O2',
#  'C1C2C3OCC3CCN12',
#  'CC1(C)CC(=O)C1O',
#  'CC1C2OC1C2C',
#  'CC1N=COCOC1=N',
#  'C1C2C1C1CC2CO1',
#  'CC1OC2C(=O)NC12C',
#  'COC1(CC1)C#CC=O',
#  'OCC(CC#C)OC=O',
#  'NC1CC2(CC2)OC1=O',
#  'CC1CC2OC3(C)C2C13',
#  'CC1CC(=N)OCO1',
#  'CC1(CC1)C#CCC#N',
#  'CN1N=CC(C)=NC1=O',
#  'OCC(CC1CC1)C#N',
#  'CC12CC1(CCO2)C#N',
#  'CC1COC(=O)C1C#C',
#  'O=CN1CCCC2CC12',
#  'CC(=N)OC1CN2CC12',
#  'CN1CC1CC(F)(F)F',
#  'OCC1(CO1)C#CC#N',
#  'CC12CCCC1(N2)C#N',
#  'N#CC1=CC=CC=C1',
#  'CN1C(=O)C=C(C)C1=N',
#  'CC1C=CC2CC12O',
#  'O=C(C#C)C(=O)C1CN1',
#  'CC#CC1(C)OC2CC12',
#  'CN1CC2NC2(C1)C=O',
#  'C1C2C3C4C5C2C(C13)N45',
#  'NC1=CC=NC=C1F',
#  'ON=C1CC(C1)C#C',
#  'C1C2NC2C11CCC=C1',
#  'CC1(O)CC1([NH3+])C([O-])=O',
#  'CC1C2CC(O)C12C#N',
#  'COC1(C)CC11COC1',
#  'C1OC2C3NC3COC12',
#  'CC#CC(C)(C)O',
#  'COC1=NC(C)=C(N)N1',
#  'N=C1OC2CC1C1OC21',
#  'CC1(CO1)C1(CC1)C#N',
#  'O=CC1CN1CC#N',
#  'OCC(=O)OC(=N)C#N',
#  'CCC1C2C(CN12)OC',
#  'CCC1=CC2NC2C1O',
#  'CC1=CCCC2(C)NC12',
#  'NC1=NC=C(F)C(F)=C1',
#  'OC1CC11C=CC2OC12',
#  'OCC1CN2CC12C=O',
#  'COC1C2C3C4C1C2N34',
#  'O=C1OCC2=C1ON=N2',
#  'CC12C3C1N1CC2(O)C31',
#  'CC1=CCC2(COC2)C1',
#  'OCC1C2C3CC1(O)C23',
#  'CC1=CN=C(N1)C#C',
#  'OC1C2CC=CC2C1=O',
#  'O=C1CCC2CCC2O1',
#  'C#CC12CC(CCC1)O2',
#  'CCC(N=COC)C#C',
#  'C1OC2OC3C4OC13C24',
#  'NC1=COC(C[NH3+])=C1[O-]',
#  'CC1=CC(=O)CCOC1',
#  'NC(=O)OC1(CC1)C#N',
#  'C1OC2OC=NC3C1C23',
#  'CC#CC1=CCCC1',
#  'N=C1NC=NOC1=O',
#  'CC(O)CC1CC1O',
#  'CC1(C)CC(C1)N1CC1',
#  'C1CC(C1)C1=CN=NO1',
#  'CC1=CNC(C)=C1N',
#  'OC12C3CC1=CCCC23',
#  'CCN1C(C)C=CC1=O',
#  'CN1C2CC3(O)CC3C12',
#  '[NH3+]C(CC([O-])=O)C1CN1',
#  'CC(C#N)C1COC1=O',
#  'O1C=CC2=C1N=CC=N2',
#  'N#CCNCC1CCO1',
#  ...]

# %%
'''
#list of SMILES and list of correponding SELFIES
selfies_dataset = []

for i in range(len(smiles)):
  local_sf = sf.encoder(smiles[i])
  selfies_dataset.append(local_sf)
  '''
# Out:
# '\n#list of SMILES and list of correponding SELFIES\nselfies_dataset = []\n\nfor i in range(len(smiles)):\n  local_sf = sf.encoder(smiles[i])\n  selfies_dataset.append(local_sf)\n  '

# %%
selfies_dataset = []

for i in range(len(smiles)):
    try:
        local_sf = sf.encoder(smiles[i])
        selfies_dataset.append(local_sf)
    except Exception as e:
        print(f"Error encoding SMILES at index {i}: {e}")
        continue  # Skip to the next iteration
# Out:
# Error encoding SMILES at index 320: input violates the currently-set semantic constraints
# 	SMILES: CN1N=CC=C1N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 600: input violates the currently-set semantic constraints
# 	SMILES: NC1=CN=C(O1)N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 620: input violates the currently-set semantic constraints
# 	SMILES: NC1=C(NN=C1)N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 1022: input violates the currently-set semantic constraints
# 	SMILES: O=C1ON=C(O1)N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 1197: input violates the currently-set semantic constraints
# 	SMILES: NC1=CC(=NO1)N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 2989: input violates the currently-set semantic constraints
# 	SMILES: NC1=NOC=C1N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 3545: input violates the currently-set semantic constraints
# 	SMILES: CC1=NNN=C1N(=O)=O
# 	Errors:
# 	[N with 5 bond(s) - a max. of 3 bond(s) was specified]
#
# Error encoding SMILES at index 3668: input violates the currently-set semantic constraints
# 	SMILES: NC1=CNC(=N1)N(=O)=O
# 	Errors:
Branch1][Ring1][C][#N][C][Ring1][=Branch1][O]', '[C][C][=C][C][=Branch1][Branch1][=C][O][Ring1][Branch1][C][C][O][Ring1][Ring1]', '[O][=C][N][Branch1][Ring1][C][=O][C][=Branch1][C][=O][C][#C]', '[C][C][Branch1][C][C][N][C][C][Ring1][Ring1][C][C][#N]', '[C][C][Branch1][Ring1][C][#N][C][=C][N][C][=N][Ring1][Branch1]', '[C][O][C][C][C][Branch1][C][C][O][C][Ring1][Branch1][C]', '[C][C][C][C][Ring1][Ring2][C][Ring1][Ring1][C][C][O][C][Ring1][Branch1][Ring1][Ring1]', '[C][C][=C][C][C][C][Branch1][C][O][C][Ring1][#Branch1][C][Ring1][=Branch1]', '[C][C][C][C][C][C][Ring1][Ring1][O][C][Ring1][Branch1][=O]', '[C][C][Branch1][C][O][C][C][C][O][C][Ring1][Ring2][=O]', '[C][C][=C][C][C][Branch1][Ring1][C][O][C][C][Ring1][Branch2][Ring1][Branch1]', '[O][=C][N][C][=C][N][=C][Ring1][Branch1]', '[C][C][Branch1][C][C][C][C][C][O][C][Ring1][Ring1][C][Ring1][=Branch1][Ring1][Branch1]', '[C][O][C][=N][C][=C][N][=N][O][Ring1][Branch1]', '[C][O][C][=N][C][C][N][C][Ring1][Branch2][Ring1][Ring1]', '[C][N][C][=N][C][Branch1][Ring1][C][#C][=C][Ring1][#Branch1][N]', '[O][=C][C][C][=N][C][=C][N][=C][Ring1][=Branch1]', '[O][N][=C][C][C][N][C][C][Ring1][=Branch1][C][Ring1][=Branch1][Ring1][Ring2]', '[C][C][C][=C][C][C][Branch1][Ring1][C][=O][C][Ring1][Branch2][Ring1][Branch1]', '[C][C][C][N][=C][N][Branch1][C][C][C][Ring1][=Branch1][=O]', '[O][C][C][Branch1][C][O][C][O][C][C][#C]', '[C][N][Branch1][Ring1][C][=N][C][=Branch1][C][=O][N][C][=O]', '[O][C][C][C][Ring1][Ring1][N][Branch1][Ring1][C][=O][C][=O]', '[C][C][C][C][C][O][C][C][Ring1][#Branch1][O]', '[C][C][C][N][C][Ring1][Ring2][Branch1][Ring1][C][=O][C][#N]', '[O][C][C][C][Branch1][C][O][C][C][C][Ring1][Branch1][C][Ring1][Ring2]', '[C][O][C][C][=C][C][C][C][Ring1][=Br ...

# %%
#for producing corresponding one-hot vectors
alphabet = sf.get_alphabet_from_selfies(selfies_dataset)
alphabet.add("[nop]")  # [nop] is a special padding symbol
alphabet = list(sorted(alphabet))

pad_to_len = max(sf.len_selfies(s) for s in selfies_dataset)
symbol_to_idx = {s: i for i, s in enumerate(alphabet)}

labels = []
one_hot_vectors = []
for i in range(len(selfies_dataset)):

  label, one_hot = sf.selfies_to_encoding(selfies=selfies_dataset[i], vocab_stoi=symbol_to_idx,
                                          pad_to_len=pad_to_len, enc_type="both")
  labels.append(label)
  one_hot_vectors.append(one_hot)

# %%
np.array(one_hot_vectors).shape[1:]
# Out:
# (21, 27)

# %%
plt.imshow(np.array(one_hot_vectors)[310,:,:])

# %%
import numpy as np
import keras
from keras import ops, Model
from keras.layers import Input, Dense, Lambda, Flatten, Reshape
from keras.losses import binary_crossentropy
import tensorflow as tf

# ---- Parameters ----
input_shape = np.array(one_hot_vectors).shape[1:]
original_dim = np.prod(input_shape)
latent_dim = 2

# ---- Sampling Function ----
def sampling(args):
    z_mean, z_log_var = args
    epsilon = tf.random.normal(shape=(tf.shape(z_mean)[0], latent_dim))
    return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# ---- Encoder ----
inputs = Input(shape=input_shape, name="encoder_input")
x = Flatten()(inputs)
x = Dense(128, activation="relu")(x)
z_mean = Dense(latent_dim, name="z_mean")(x)
z_log_var = Dense(latent_dim, name="z_log_var")(x)
z = Lambda(sampling, output_shape=(latent_dim,), name="z")([z_mean, z_log_var])

encoder = Model(inputs, [z_mean, z_log_var, z], name="encoder")

# ---- Decoder ----
latent_inputs = Input(shape=(latent_dim,), name="z_sampling")
x = Dense(128, activation="relu")(latent_inputs)
x = Dense(original_dim, activation="sigmoid")(x)
outputs = Reshape(input_shape)(x)
decoder = Model(latent_inputs, outputs, name="decoder")

# ---- VAE Model (Custom Subclass) ----
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        return reconstructed

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstructed = self.decoder(z)

            # Flatten for loss computation
            data_flat = ops.reshape(data, (ops.shape(data)[0], -1))
            recon_flat = ops.reshape(reconstructed, (ops.shape(reconstructed)[0], -1))

            # Reconstruction and KL losses
            reconstruction_loss = ops.sum(binary_crossentropy(data_flat, recon_flat), axis=-1)
            kl_loss = -0.5 * ops.sum(1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var), axis=-1)
            total_loss = ops.mean(reconstruction_loss + kl_loss)

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        return {"loss": total_loss}

# ---- Instantiate & Compile ----
vae = VAE(encoder, decoder)
vae.compile(optimizer="adam")

# ---- Summaries ----
encoder.summary()
decoder.summary()
vae.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 21, 27)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 567)       │          0 │ encoder_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     72,704 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │        258 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 2)         │        258 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Lambda)          │ (None, 2)         │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 73,220 (286.02 KB)
#  Trainable params: 73,220 (286.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ z_sampling (InputLayer)         │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 567)            │        73,143 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 21, 27)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,527 (287.21 KB)
#  Trainable params: 73,527 (287.21 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Functional)            │ ((None, 2), (None, 2), │        73,220 │
# │                                 │ (None, 2))             │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 21, 27)         │        73,527 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,747 (573.23 KB)
#  Trainable params: 146,747 (573.23 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
data = np.array(one_hot_vectors)
vae.fit(data, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 65.4687
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.3666
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 15.5543
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.3639
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3626
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.7572
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.3797
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.0893
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.8745
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.6745
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.5236
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.4203
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.3114
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.2040
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.0951
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0110
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9018
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8173
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6995
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5662
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4833
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3497
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2307
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1232
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0357
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.9619
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9211
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8869
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8771
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8500
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8482
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8375
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8366
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8245
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8339
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8143
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8075
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.8167
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8168
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8004
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7965
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7986
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7791
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7745
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7835
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7930
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.7854
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7680
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7800
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7588
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7677
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7543
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7618
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7542
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7730
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7785
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7588
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7664
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7615
# Epoch 60/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7519
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7589
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7479
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7454
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7442
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7527
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.7591
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.7594
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7474
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7421
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.7697
# Epoch 71/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7414
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7432
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7496
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7422
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7420
# Epoch 76/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7514
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7506
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7428
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7423
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7535
# Epoch 81/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7478
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7402
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7571
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7362
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7500
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7420
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7428
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7320
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7312
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7414
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7441
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7442
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7378
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7335
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7367
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7334
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.7405
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7282
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7403
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7285

# %%
data.shape
# Out:
# (4992, 21, 27)

# %%
def plot_latent_representation(decoder, shape = (21,26), n=15):
    height, width = shape
    grid_x = np.linspace(-4, 4, n)
    grid_y = np.linspace(-4, 4, n)
    figure = np.zeros((height * n, width * n))
    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(height, width)
            figure[i * height: (i + 1) * height, j * width: (j + 1) * width] = digit
    plt.figure(figsize=(10, 10))
    plt.imshow(figure, cmap='Greys_r')
    plt.axis('off')
    plt.show()

# %%
def plot_latent_space(encoder, data):
    z_mean, _, _ = encoder.predict(data);
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1])
    plt.colorbar()
    plt.xlabel('z - dim 1')
    plt.ylabel('z - dim 2')
    plt.title('Latent Space')
    plt.show()

# %%
plot_latent_representation(decoder, shape = data.shape[1:]);
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
plot_latent_space(encoder, data);
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
